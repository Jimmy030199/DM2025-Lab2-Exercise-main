# %%
from pathlib import Path

# 🔹 取得目前 Notebook 所在資料夾（也就是你執行 code 的地方）
current_dir = Path.cwd()

# 🔹 在當前目錄建立 .kaggle 資料夾
kaggle_dir = current_dir / ".kaggle"
kaggle_dir.mkdir(exist_ok=True)

# 🔹 輸出實際建立的路徑
print(f"Kaggle 資料夾建立位置：{kaggle_dir.resolve()}")
# Out:
# Kaggle 資料夾建立位置：C:\Users\User\Desktop\DM2025-Lab2-Exercise-main\.kaggle

# %%
import os
from pathlib import Path

# 告訴 Kaggle CLI 金鑰在哪裡
os.environ["KAGGLE_CONFIG_DIR"] = str(Path.cwd() / ".kaggle")
# Out:
# $KAGGLE_CONFIG_DIR

# %%
# !jupyter nbconvert --to script DM2025-Lab2-Master-Phase_1.ipynb
# Out:
# [NbConvertApp] Converting notebook DM2025-Lab2-Master-Phase_1.ipynb to script
# [NbConvertApp] Writing 38864 bytes to DM2025-Lab2-Master-Phase_1.py

# %%
# !jupyter nbconvert --to script DM2025-Lab2-Master-Phase_2_Main.ipynb
# Out:
# [NbConvertApp] Converting notebook DM2025-Lab2-Master-Phase_2_Main.ipynb to script
# [NbConvertApp] Writing 71701 bytes to DM2025-Lab2-Master-Phase_2_Main.py

# %%
# !jupyter nbconvert --to script DM2025-Lab2-Master-Phase_2_Bonus.ipynb
# Out:
# [NbConvertApp] Converting notebook DM2025-Lab2-Master-Phase_2_Bonus.ipynb to script
# [NbConvertApp] Writing 81149 bytes to DM2025-Lab2-Master-Phase_2_Bonus.py
